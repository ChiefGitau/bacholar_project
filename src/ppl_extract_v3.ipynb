# %%
from helpers import detectron2_helper
import os

# %%
os.path.abspath('../paper_model')

root = os.path.abspath('/home/hidde/Desktop/git/Vu/Seeing_the_words/paper_model')
root_image = root + '/example_img/example_1.jpg'
url_img = 'https://ik.imagekit.io/seeingthewords/data/runwayml/prompt_2/SD-RUN-P2-191.jpg?updatedAt=1687944153125'

# %%
prediction, frame, image =   detectron2_helper.detect_elements(detectron2_helper.get_image_link(url_img))
# Out:
# /home/hidde/.local/lib/python3.8/site-packages/detectron2/structures/image_list.py:88: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   max_size = (max_size + (stride - 1)) // stride * stride
# /home/hidde/.local/lib/python3.8/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
detectron2_helper.vis_image(image)

# %%
detectron2_helper.vis_prediction(image, prediction)

# %%
image_list = detectron2_helper.get_human_element(image, prediction)

# %%
detectron2_helper.vis_prediction(image, prediction)

# %%
len(image_list)
# Out:
# 1

# %%
import age_sex

age = age_sex.model_age()
gender =age_sex.model_gender()
# Out:
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# I0727 21:18:14.119935 146604 upgrade_proto.cpp:55] Attempting to upgrade input file specified using deprecated V1LayerParameter: /home/hidde/Desktop/git/Vu/Seeing_the_words/paper_model/deploy_age.prototxt
# I0727 21:18:14.119975 146604 upgrade_proto.cpp:63] Successfully upgraded file specified using deprecated V1LayerParameter
# I0727 21:18:14.119982 146604 upgrade_proto.cpp:69] Attempting to upgrade input file specified using deprecated input fields: /home/hidde/Desktop/git/Vu/Seeing_the_words/paper_model/deploy_age.prototxt
# I0727 21:18:14.119989 146604 upgrade_proto.cpp:72] Successfully upgraded file specified using deprecated input fields.
# W0727 21:18:14.119990 146604 upgrade_proto.cpp:74] Note that future Caffe releases will only support input layers and not input fields.
# I0727 21:18:14.120007 146604 net.cpp:53] Initializing net from parameters:
# name: "CaffeNet"
# state {
#   phase: TEST
#   level: 0
# }
# ...

# %%
from matplotlib import pyplot as plt
import caffe
test_image = image_list[1]

# %%
len(image_list)
# Out:
# 2

# %%
_ = plt.imshow(test_image)

# %%
age_list, gender_list = age_sex.get_labels()

# %%
age_sex.model_predict(test_image, age, age_list)
# Out:
# '(60, 100)'

# %%
age_sex.model_predict(test_image, gender, gender_list)
# Out:
# 'Female'

# %%
len(image_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 len(image_list)
#
# NameError: name 'image_list' is not defined

# %%
import image_data

# %%
# Out:
# loc='stabilityai' contains  len(data)=200
# loc='SG161222' contains  len(data)=200
# loc='runwayml' contains  len(data)=200
# loc='prompthero' contains  len(data)=100
# loc='nitrosocke' contains  len(data)=200
# loc='mid_journey' contains  len(data)=138
# loc='dall_e_2' contains  len(data)=100
# loc='dream' contains  len(data)=100
# loc='CompVis' contains  len(data)=100
# loc='base' contains  len(data)=5

# %%
data[0]
# Out:
# {'type': 'file',
#  'name': 'SD-STABLILITY-P2-72.jpg',
#  'createdAt': '2023-06-28T09:29:53.009Z',
#  'updatedAt': '2023-06-28T09:29:53.294Z',
#  'fileId': '649bfd9106370748f2c120ee',
#  'tags': None,
#  'AITags': None,
#  'versionInfo': {'id': '649bfd9106370748f2c120ee', 'name': 'Version 1'},
#  'embeddedMetadata': {'XResolution': 1,
#   'YResolution': 1,
#   'DateCreated': '2023-06-28T09:29:53.294Z',
#   'DateTimeCreated': '2023-06-28T09:29:53.294Z'},
#  'customCoordinates': None,
#  'customMetadata': {},
#  'isPrivateFile': False,
#  'url': 'https://ik.imagekit.io/seeingthewords/data/stabilityai/prompt_2/SD-STABLILITY-P2-72.jpg',
#  'thumbnail': 'https://ik.imagekit.io/seeingthewords/tr:n-ik_ml_thumbnail/data/stabilityai/prompt_2/SD-STABLILITY-P2-72.jpg',
#  'fileType': 'image',
#  'filePath': '/data/stabilityai/prompt_2/SD-STABLILITY-P2-72.jpg',
#  'height': 512,
#  'width': 512,
#  'size': 44098,
#  'hasAlpha': False,
#  'mime': 'image/jpeg'}

# %%
import human_re_2

df = human_re_2.human_recon(data)
# Out:
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# I0713 21:26:58.018280  8463 upgrade_proto.cpp:55] Attempting to upgrade input file specified using deprecated V1LayerParameter: /home/hidde/Desktop/git/Vu/Seeing_the_words/paper_model/deploy_age.prototxt
# I0713 21:26:58.018334  8463 upgrade_proto.cpp:63] Successfully upgraded file specified using deprecated V1LayerParameter
# I0713 21:26:58.018340  8463 upgrade_proto.cpp:69] Attempting to upgrade input file specified using deprecated input fields: /home/hidde/Desktop/git/Vu/Seeing_the_words/paper_model/deploy_age.prototxt
# I0713 21:26:58.018347  8463 upgrade_proto.cpp:72] Successfully upgraded file specified using deprecated input fields.
# W0713 21:26:58.018347  8463 upgrade_proto.cpp:74] Note that future Caffe releases will only support input layers and not input fields.
# I0713 21:26:58.018368  8463 net.cpp:53] Initializing net from parameters:
# name: "CaffeNet"
# state {
#   phase: TEST
#   level: 0
# }
# ...

# %%
df['generator'].unique()
# Out:
# array(['stabilityai', 'SG161222', 'runwayml', 'prompthero', 'nitrosocke',
#        'mid_journey', 'dall_e_2', 'dream', 'CompVis', 'base'],
#       dtype=object)

# %%
test = df.loc[df['generator'] == 'mid_journey']

# %%
test.head()
# Out:
#                                               image_id    generator  number  \
# 900  https://ik.imagekit.io/seeingthewords/data/mid...  mid_journey       3
# 901  https://ik.imagekit.io/seeingthewords/data/mid...  mid_journey       4
# 902  https://ik.imagekit.io/seeingthewords/data/mid...  mid_journey       2
# 903  https://ik.imagekit.io/seeingthewords/data/mid...  mid_journey       3
# 904  https://ik.imagekit.io/seeingthewords/data/mid...  mid_journey       3
#
#      female  male                                        age_details
# 900       2     1           [[Female, 28], [Female, 28], [Male, 80]]
# 901       3     1  [[Female, 28], [Female, 28], [Female, 80], [Ma...
# 902       1     1                         [[Female, 80], [Male, 10]]
# 903       2     1           [[Female, 10], [Female, 80], [Male, 28]]
# 904       2     1           [[Female, 40], [Female, 28], [Male, 28]]

# %%
df.to_csv('data_csv/prompt_2/data_ppl_detectron.csv')

# %%
data_3 = image_data.get_target_data("prompt_3")
# Out:
# loc='stabilityai' contains  len(data)=200
# loc='SG161222' contains  len(data)=200
# loc='runwayml' contains  len(data)=200
# loc='prompthero' contains  len(data)=100
# loc='nitrosocke' contains  len(data)=200
# loc='mid_journey' contains  len(data)=102
# loc='dall_e_2' contains  len(data)=100
# loc='dream' contains  len(data)=100
# loc='CompVis' contains  len(data)=100
# loc='base' contains  len(data)=5

# %%
df_3 = human_re_2.human_recon(data_3)
df_3['generator'].unique()
# Out:
#   0%|          | 0/1307 [00:00<?, ?it/s]/home/hidde/.local/lib/python3.8/site-packages/detectron2/structures/image_list.py:88: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   max_size = (max_size + (stride - 1)) // stride * stride
# ...

# %%
df_3.to_csv('data_csv/prompt_3/data_ppl_detectron.csv')

# %%
data_4 = image_data.get_target_data("prompt_4")
# Out:
# loc='stabilityai' contains  len(data)=200
# loc='SG161222' contains  len(data)=200
# loc='runwayml' contains  len(data)=200
# loc='prompthero' contains  len(data)=100
# loc='nitrosocke' contains  len(data)=200
# loc='mid_journey' contains  len(data)=128
# loc='dall_e_2' contains  len(data)=100
# loc='dream' contains  len(data)=100
# loc='CompVis' contains  len(data)=100
# loc='base' contains  len(data)=5

# %%
df_4 = human_re_2.human_recon(data_4)
df_4['generator'].unique()
# Out:
#   0%|          | 0/1333 [00:00<?, ?it/s]/home/hidde/.local/lib/python3.8/site-packages/detectron2/structures/image_list.py:88: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   max_size = (max_size + (stride - 1)) // stride * stride
# ...

# %%
df_4.to_csv('data_csv/prompt_4/data_ppl_detectron.csv')
